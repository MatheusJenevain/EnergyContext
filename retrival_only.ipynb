# %%
from transformers import pipeline
from datasets import load_dataset
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Load the question answering pipeline with a model fine-tuned for question answering
question_answerer = pipeline("question-answering", model="distilbert-base-uncased-distilled-squad")

# Load the dataset
dataset = load_dataset("Open-Orca/OpenOrca")

# Extract contexts and system prompts and turn them into a DataFrame
contexts = dataset["train"]["response"]
system_prompts = dataset["train"]["system_prompt"]
df = pd.DataFrame({'context': contexts, 'system_prompt': system_prompts})

# Define your question
question = "What are thermal mass systems?"

# Filter for relevant system prompts
def is_relevant_prompt(prompt, keywords):
    return any(keyword.lower() in prompt.lower() for keyword in keywords)

# Define keywords to identify relevant system prompts
prompt_keywords = ["thermal mass system", "heat storage", "thermal energy storage"]

# Filter system prompts for relevance
relevant_prompts = [prompt for prompt in system_prompts if is_relevant_prompt(prompt, prompt_keywords)]

# Print the selected system prompts for debugging
print("Relevant system prompts:")
for i, prompt in enumerate(relevant_prompts[:10]):  # Print only the top 10 for brevity
    print(f"System Prompt {i+1}: {prompt}\n")

# Combine relevant system prompts with contexts
df['combined'] = df.apply(lambda row: ' '.join([row['system_prompt'], row['context']]) 
                          if row['system_prompt'] in relevant_prompts else row['context'], axis=1)

# Retrieve relevant contexts using TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(max_features=50000)
tfidf_matrix = tfidf_vectorizer.fit_transform(df['combined'])

# Transform the question into the same vector space
question_vector = tfidf_vectorizer.transform([question])

# Compute cosine similarity between the question and all contexts
cosine_similarities = cosine_similarity(question_vector, tfidf_matrix).flatten()

# Set a high threshold for cosine similarity
threshold = 0.1
top_n_indices = np.where(cosine_similarities > threshold)[0]
top_contexts = df.iloc[top_n_indices]['combined'].drop_duplicates().tolist()

# Filter contexts for relevance and length
def is_relevant_context(context, keywords):
    return any(keyword.lower() in context.lower() for keyword in keywords)

# Define more specific keywords for context filtering
context_keywords = ["thermal mass system", "heat storage", "thermal energy storage"]

# Filter for relevant contexts
relevant_contexts = [context for context in top_contexts if is_relevant_context(context, context_keywords)]

# Print the selected contexts for debugging
print("Relevant contexts:")
for i, context in enumerate(relevant_contexts[:10]):  # Print only the top 10 for brevity
    print(f"Context {i+1}: {context}\n")

# Concatenate the top relevant contexts into a single string
combined_contexts = " ".join(relevant_contexts)

# Create a detailed system prompt for the AI
system_prompt = "You are an AI assistant that helps people find information. Provide a detailed answer so the user doesn’t need to search outside to understand the answer."

# Combine the system prompt with the combined contexts
final_context = system_prompt + " " + combined_contexts

# Perform the question answering on the combined contexts
detailed_result = question_answerer(question=question, context=final_context)

# Print the result for debugging
print("QA Result:", detailed_result)

# Extract the answer span from the context using the provided indices
answer_start = detailed_result['start']
answer_end = detailed_result['end']
answer = final_context[answer_start:answer_end].strip()

# Print the detailed answer
print("Detailed Answer:", answer)
# Out:
# Relevant system prompts:
# Relevant contexts:
# Context 1: Yes, the question is answered satisfactorily. The answer provided highlights a key function of a thermal mass system, which is to store solar energy in the form of heat at useful temperatures for daily or interseasonal durations.
#
# Context 2: Title: "Harnessing Solar Energy with Thermal Mass Systems: Maximizing Efficiency and Reducing Demand Through High Specific Heat Capacity Materials"
#
# Context 3: Among the options provided, air does not accept heat very well as it is a poor conductor of heat. Now, let's examine each of the options to better understand their thermal conductivity and ability to accept and conduct heat.
#
# 1. Corn - Being a plant-based material, corn can absorb some heat, but it is not a particularly good conductor. Its thermal conductivity depends on several factors, such as moisture content and density. However, when compared to metals or other solid materials, it does not conduct heat very well.
#
# 2. Air - Air is an insulator and a poor conductor of heat due to the vast space between its molecules. This makes it difficult for heat to transfer through the air. In comparison to other gases, air has relatively low thermal conductivity, making it an ideal insulating medium and demonstrating its inability to accept heat very well.
#
# 3. Coal - Coal, as a carbon-rich substance, can absorb and retain some heat. However, it is not a highly effective conductor, especially compared to metals. It has a relatively low thermal conductivity, which makes it suitable for applications such as heat storage, fuel for combustion, and smelting processes.
#
# 4. Fats - Fats are organic compounds with relatively low thermal conductivity compared to metals or water. They can insulate and retain heat to some extent but are not as effective in conducting heat.
#
# 5. Oil - Oil, being a liquid, conducts heat better than air but not as effectively as some solids. Although its thermal conductivity is still relatively low compared to some metals and water, it can transfer heat efficiently through convection processes.
#
# 6. Rust - Rust, or iron oxide, has a lower thermal conductivity than pure iron, meaning it does not conduct heat very well. This makes rust a poor heat conductor, although not as poor as air.
#
# 7. Man - Human beings are not good conductors of heat. Our bodies have several mechanisms to regulate temperature, such as sweating and shivering. Moreover, our skin, hair, and fat layers serve as insulators, and blood flow also helps to distribute and regulate heat.
#
# 8. Mold - Mold, being a living organism, is not a strong conductor of heat. Mold prefers moist environments that are neither too hot nor too cold and would likely grow in areas where heat is not well-conducted.
#
# In conclusion, among the options given, air does not accept heat very well and is a poor conductor of heat. Other substances listed, such as corn, coal, fats, oil, rust, humans, and mold, also have relatively low thermal conductivity or do not effectively accept and conduct heat as compared to materials like metals or water. However, air stands out as the poorest conductor among them.
#
# Context 4: Thermal mass reduces the need for auxiliary heating and cooling equipment in a building. By effectively absorbing and storing heat from the Sun or other sources during the day and releasing it when the temperature drops at night, thermal mass helps maintain a comfortable and stable indoor temperature. This natural process of heat absorption and release reduces the dependence on artificial heating and cooling systems, such as furnaces, air conditioners, and heat pumps. Consequently, this can result in lower energy consumption, reduced greenhouse gas emissions, and cost savings for the occupants of the building. The careful design and positioning of thermal mass elements, considering factors like climate, daylighting, and shading conditions, are essential for achieving optimal results in thermal energy storage and maintaining a comfortable indoor environment.
#
# Context 5: Title: "Harnessing Solar Energy through Thermal Mass Systems for Daily and Interseasonal Applications"
#
# Context 6: What are the advantages of using phase change materials like paraffin wax and Glauber's salt for thermal energy storage, and how did the Solar Two project demonstrate the effectiveness of using molten salts for high-temperature energy storage?
#
# Context 7: Based on the information provided, the answer to the question "What is used today to hold scents that used to be used for heat?" is not explicitly stated. However, the passage does provide information on various thermal storage media that are used today, including phase change materials such as paraffin wax and Glauber's salt, as well as molten salts for storing solar energy at high temperatures. These materials are effective storage mediums because they are low-cost, readily available, and have high specific heat capacities, allowing them to deliver heat at temperatures compatible with conventional power systems.
#
# It is important to note that while the passage does not provide a direct answer to the question, it does offer valuable information on the various thermal storage methods that are used today. This information can be useful in understanding the advancements in thermal energy storage and the various applications of these storage methods in different industries.
#
# Context 8: The title of this article could be "The Benefits of Thermal Mass Systems for Storing Solar Energy". The article discusses how thermal mass systems can store solar energy in the form of heat at domestically useful temperatures for daily or interseasonal durations. It explains that thermal storage systems generally use readily available materials with high specific heat capacities such as water, earth and stone. The article also highlights the advantages of well-designed thermal mass systems, which can lower peak demand, shift time-of-use to off-peak hours and reduce overall heating and cooling requirements. Overall, the article provides a comprehensive overview of the benefits of thermal mass systems for storing solar energy and how they can contribute to more sustainable and efficient energy use.
#
# Context 9: A thermal mass system can store solar energy in the form of heat at domestically useful temperatures for daily or interseasonal durations. This stored energy can be used to lower peak demand, shift time-of-use to off-peak hours and reduce overall heating and cooling requirements.
#
# Context 10: Based on the information provided, the better option overall for thermal energy storage is likely to be phase change materials such as paraffin wax and Glauber's salt, or molten salts for high-temperature solar energy storage. These materials are low-cost, readily available, and have high specific heat capacities, making them effective storage media for delivering heat at temperatures compatible with conventional power systems. The Dover House in Massachusetts was the first to use a Glauber's salt heating system in 1948, and the Solar Two used molten salts to store 1.44 terajoules of energy with an annual storage efficiency of about 99%.
#
# QA Result: {'score': 0.1833934634923935, 'start': 11595, 'end': 11625, 'answer': 'thermal energy storage systems'}
# Detailed Answer: thermal energy storage systems

# %%
from transformers import pipeline
from datasets import load_dataset
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Load the question answering pipeline with a model fine-tuned for question answering
question_answerer = pipeline("question-answering", model="distilbert-base-uncased-distilled-squad")

# Load the dataset
dataset = load_dataset("Open-Orca/OpenOrca")

# Extract contexts and turn them into a DataFrame
contexts = dataset["train"]["response"]
df = pd.DataFrame({'context': contexts})

# Define your question
question = "What are thermal mass systems?"

# Retrieve relevant contexts using TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(max_features=50000)
tfidf_matrix = tfidf_vectorizer.fit_transform(df['context'])

# Transform the question into the same vector space
question_vector = tfidf_vectorizer.transform([question])

# Compute cosine similarity between the question and all contexts
cosine_similarities = cosine_similarity(question_vector, tfidf_matrix).flatten()

# Set a high threshold for cosine similarity
threshold = 0.1
top_n_indices = np.where(cosine_similarities > threshold)[0]
top_contexts = df.iloc[top_n_indices]['context'].drop_duplicates().tolist()

# Filter contexts for relevance and length
def is_relevant_context(context, keywords):
    return any(keyword.lower() in context.lower() for keyword in keywords)

# Define more specific keywords
keywords = ["thermal mass system", "heat storage", "thermal energy storage"]

# Filter for relevant contexts
relevant_contexts = [context for context in top_contexts if is_relevant_context(context, keywords)]

# Print the selected contexts for debugging
print("Relevant contexts:")
for i, context in enumerate(relevant_contexts[:10]):  # Print only the top 10 for brevity
    print(f"Context {i+1}: {context}\n")

# Concatenate the top relevant contexts into a single string
combined_contexts = " ".join(relevant_contexts)

# Perform the question answering on the combined contexts
result = question_answerer(question=question, context=combined_contexts)

# Print the result for debugging
print("QA Result:", result)

# Extract the answer span from the context using the provided indices
answer_start = result['start']
answer_end = result['end']
answer = combined_contexts[answer_start:answer_end].strip()

# Print the answer
print("Answer:", answer)
# Out:
# Relevant contexts:
# Context 1: Yes, the question is answered satisfactorily. The answer provided highlights a key function of a thermal mass system, which is to store solar energy in the form of heat at useful temperatures for daily or interseasonal durations.
#
# Context 2: Title: "Harnessing Solar Energy with Thermal Mass Systems: Maximizing Efficiency and Reducing Demand Through High Specific Heat Capacity Materials"
#
# Context 3: Among the options provided, air does not accept heat very well as it is a poor conductor of heat. Now, let's examine each of the options to better understand their thermal conductivity and ability to accept and conduct heat.
#
# 1. Corn - Being a plant-based material, corn can absorb some heat, but it is not a particularly good conductor. Its thermal conductivity depends on several factors, such as moisture content and density. However, when compared to metals or other solid materials, it does not conduct heat very well.
#
# 2. Air - Air is an insulator and a poor conductor of heat due to the vast space between its molecules. This makes it difficult for heat to transfer through the air. In comparison to other gases, air has relatively low thermal conductivity, making it an ideal insulating medium and demonstrating its inability to accept heat very well.
#
# 3. Coal - Coal, as a carbon-rich substance, can absorb and retain some heat. However, it is not a highly effective conductor, especially compared to metals. It has a relatively low thermal conductivity, which makes it suitable for applications such as heat storage, fuel for combustion, and smelting processes.
#
# 4. Fats - Fats are organic compounds with relatively low thermal conductivity compared to metals or water. They can insulate and retain heat to some extent but are not as effective in conducting heat.
#
# 5. Oil - Oil, being a liquid, conducts heat better than air but not as effectively as some solids. Although its thermal conductivity is still relatively low compared to some metals and water, it can transfer heat efficiently through convection processes.
#
# 6. Rust - Rust, or iron oxide, has a lower thermal conductivity than pure iron, meaning it does not conduct heat very well. This makes rust a poor heat conductor, although not as poor as air.
#
# 7. Man - Human beings are not good conductors of heat. Our bodies have several mechanisms to regulate temperature, such as sweating and shivering. Moreover, our skin, hair, and fat layers serve as insulators, and blood flow also helps to distribute and regulate heat.
#
# 8. Mold - Mold, being a living organism, is not a strong conductor of heat. Mold prefers moist environments that are neither too hot nor too cold and would likely grow in areas where heat is not well-conducted.
#
# In conclusion, among the options given, air does not accept heat very well and is a poor conductor of heat. Other substances listed, such as corn, coal, fats, oil, rust, humans, and mold, also have relatively low thermal conductivity or do not effectively accept and conduct heat as compared to materials like metals or water. However, air stands out as the poorest conductor among them.
#
# Context 4: Thermal mass reduces the need for auxiliary heating and cooling equipment in a building. By effectively absorbing and storing heat from the Sun or other sources during the day and releasing it when the temperature drops at night, thermal mass helps maintain a comfortable and stable indoor temperature. This natural process of heat absorption and release reduces the dependence on artificial heating and cooling systems, such as furnaces, air conditioners, and heat pumps. Consequently, this can result in lower energy consumption, reduced greenhouse gas emissions, and cost savings for the occupants of the building. The careful design and positioning of thermal mass elements, considering factors like climate, daylighting, and shading conditions, are essential for achieving optimal results in thermal energy storage and maintaining a comfortable indoor environment.
#
# Context 5: Title: "Harnessing Solar Energy through Thermal Mass Systems for Daily and Interseasonal Applications"
#
# Context 6: What are the advantages of using phase change materials like paraffin wax and Glauber's salt for thermal energy storage, and how did the Solar Two project demonstrate the effectiveness of using molten salts for high-temperature energy storage?
#
# Context 7: Based on the information provided, the answer to the question "What is used today to hold scents that used to be used for heat?" is not explicitly stated. However, the passage does provide information on various thermal storage media that are used today, including phase change materials such as paraffin wax and Glauber's salt, as well as molten salts for storing solar energy at high temperatures. These materials are effective storage mediums because they are low-cost, readily available, and have high specific heat capacities, allowing them to deliver heat at temperatures compatible with conventional power systems.
#
# It is important to note that while the passage does not provide a direct answer to the question, it does offer valuable information on the various thermal storage methods that are used today. This information can be useful in understanding the advancements in thermal energy storage and the various applications of these storage methods in different industries.
#
# Context 8: The title of this article could be "The Benefits of Thermal Mass Systems for Storing Solar Energy". The article discusses how thermal mass systems can store solar energy in the form of heat at domestically useful temperatures for daily or interseasonal durations. It explains that thermal storage systems generally use readily available materials with high specific heat capacities such as water, earth and stone. The article also highlights the advantages of well-designed thermal mass systems, which can lower peak demand, shift time-of-use to off-peak hours and reduce overall heating and cooling requirements. Overall, the article provides a comprehensive overview of the benefits of thermal mass systems for storing solar energy and how they can contribute to more sustainable and efficient energy use.
#
# Context 9: A thermal mass system can store solar energy in the form of heat at domestically useful temperatures for daily or interseasonal durations. This stored energy can be used to lower peak demand, shift time-of-use to off-peak hours and reduce overall heating and cooling requirements.
#
# Context 10: Based on the information provided, the better option overall for thermal energy storage is likely to be phase change materials such as paraffin wax and Glauber's salt, or molten salts for high-temperature solar energy storage. These materials are low-cost, readily available, and have high specific heat capacities, making them effective storage media for delivering heat at temperatures compatible with conventional power systems. The Dover House in Massachusetts was the first to use a Glauber's salt heating system in 1948, and the Solar Two used molten salts to store 1.44 terajoules of energy with an annual storage efficiency of about 99%.
#
# QA Result: {'score': 0.4544660449028015, 'start': 11440, 'end': 11470, 'answer': 'thermal energy storage systems'}
# Answer: thermal energy storage systems
